# %%
import pandas as pd
import numpy 
import matplotlib.pyplot as plt
from scipy import stats

# %%
yelp_df = pd.read_csv('yelp_review_analysis.csv',encoding='iso-8859-1')
#yelp_df[yelp_df['name']=='Socca Restaurant']
yelp_df.head()
# Out:
#    compound  compound_by_sent  median_cmpd  median_neg  median_neu  \
# 0    0.1346            0.0497       0.0000       0.000       0.858
# 1    0.0624            0.0624       0.0000       0.061       0.808
# 2    0.2836            0.2691       0.3182       0.000       0.799
# 3    0.1785            0.1455       0.0000       0.000       0.811
# 4    0.2955            0.2688       0.3818       0.000       0.814
#
#    median_pos                  name  negative  negative_by_sent  neutral  \
# 0       0.000     Maxs Restaurants    0.0876            0.1100   0.8159
# 1       0.115          Franceschis    0.0619            0.0619   0.8240
# 2       0.149  Butterfly Restaurant    0.0483            0.0429   0.7384
# 3       0.049           La Terrasse    0.0676            0.0690   0.7766
# 4       0.180     Titas Restaurant    0.0560            0.0585   0.7835
#
#     ...    positive_by_sent  range_cmpd_max  range_cmpd_min  range_neg_max  \
# 0   ...              0.0783          0.7269         -0.4404           1.00
# 1   ...              0.1142          0.7050         -0.4336           0.15
# 2   ...              0.1848          0.9546         -0.8377           1.00
# 3   ...              0.1410          0.9523         -0.9015           1.00
# 4   ...              0.1470          0.8550         -0.3818           1.00
#
#    range_neg_min  range_neu_max  range_neu_min  range_pos_max  range_pos_min  \
# 0            0.0            1.0          0.000          0.357            0.0
# 1            0.0            1.0          0.527          0.343            0.0
# 2            0.0            1.0          0.000          1.000            0.0
# 3            0.0            1.0          0.000          1.000            0.0
# 4            0.0            1.0          0.000          0.610            0.0
#
#    rating
# 0     3.0
# 1     2.0
# 2     3.5
# 3     2.5
# 4     3.0
#
# [5 rows x 23 columns]

# %%
len(yelp_df[yelp_df['compound'] > 0])
# Out:
# 271

# %%
len(yelp_df[yelp_df['rating'] == 4.0])
# Out:
# 69

# %%
len(yelp_df[yelp_df['num_reviews']>0])
# Out:
# 277

# %%
max(yelp_df['negative'])
# Out:
# 0.21079999999999999

# %%
min(yelp_df['negative'])
# Out:
# 0.0

# %%
fig = plt.figure()

#scatter plot1 compound score vs. yelp restaurant rating

plt.scatter(yelp_df['compound'], yelp_df['rating'], s=50)
plt.xlabel('compound score')
plt.ylabel('Rating')
plt.show()

# %%
#scatter plot2 negative score vs. yelp restaurant rating

plt.scatter(yelp_df['negative'], yelp_df['rating'], s=50)
plt.xlabel('negative score')
plt.ylabel('Rating')
plt.show()

# %%
#scatter plot3 positive score vs. yelp restaurant rating

plt.scatter(yelp_df['positive'], yelp_df['rating'], s=50)
plt.xlabel('positive score')
plt.ylabel('Rating')
plt.show()

# %%
## number of restrau having reviews out of total restraunt population
portions = [len(yelp_df[yelp_df['num_reviews']>0]), len(yelp_df[yelp_df['num_reviews']<1])]
colors = ['orange', 'grey']
labels = ['Rest_w/reviews,', 'Rest_w/o reviews']
plt.pie(portions, labels=labels, autopct='%1.1f%%', shadow=True, colors = colors)
plt.axis('equal')
plt.title('Total % of restraunts having reviews')
plt.show()

# %%
## Restaunts rating distribution
fig = plt.figure(figsize=(8, 8))
portions = yelp_df.groupby('rating')['rating'].count()
# portions
# #colors = ['orange', 'grey', 'lightblue','lightred',]
labels = portions.index
plt.pie(portions, labels=labels, autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.title('Total % of restraunts having reviews', y=1.05)
plt.show()

# %%
# compound_by_sent vs  median compound score
plt.figure()

plt.scatter(yelp_df['compound_by_sent'], yelp_df['median_cmpd'], s=100, alpha=0.5,marker='o', color='gold', edgecolor='black')
plt.xlabel('compound score by sentence per restaurant')
plt.ylabel('median compound score per restaurant')
plt.margins(0.2,0.1)
plt.show()

# %%
# compound_by_sent vs ratings
plt.scatter(yelp_df['compound_by_sent'], yelp_df['rating'], s=50)
plt.xlabel('compound score by sentence per restaurant')
plt.ylabel('Rating')
plt.show() #looks same as compound vs ratings - almost

# %%
#negative score by sentence vs number of reviews
plt.scatter(yelp_df['negative_by_sent'], yelp_df['num_reviews'], s=100,color='green', marker='+')
plt.xlabel('Negative score')
plt.ylabel('Number of reviews')
plt.show()
# does not matter the number of reviews, the negative scorer for most restaurants ranges frm 0-0.10

# %%
#calculating correlation between negative score and number of reviews
corr = numpy.corrcoef(yelp_df['negative_by_sent'], yelp_df['num_reviews'])[0,1]
corr
# Out:
# 0.036960579892247603

# %%
#calculating correlation and p-value
negscore_corr = scipy.stats.pearsonr(yelp_df['negative_by_sent'], yelp_df['num_reviews'])
negscore_corr
#the output above suggests - the correlation between negative score and number of reviews of restaurant is only 0.03 which means there is no strong correlation. To top that, the -pvalue is 0.52 ( pvalue>0.5) which means correlation is not significant
# Out:
# (0.036960579892247575, 0.52365502945134201)

# %%
#pos_range_max vs num of reviews --> to see if numb of reviews are less, it skews the sentiment scores
plt.figure(figsize=(6, 4))
plt.scatter(yelp_df['range_pos_max'], yelp_df['num_reviews'], s=80,alpha=0.5,
            color='lightgrey',edgecolor='black',marker='s')
plt.xlabel('Max Positive score range for Restraunts')
plt.ylabel('Number of reviews for Restraunts')
plt.show()
#the graph below shows that lesser the reviews (less than 100) have less max pos_score (<1)
## not important inference

# %%
#calculating pearson correlation
maxpos_corr = scipy.stats.pearsonr(yelp_df['range_pos_max'], yelp_df['num_reviews'])
maxpos_corr

# the low p-value suggests that thre is high probabilty data represents hypothesis, 
#but since correlatin value is too low, only 0.39, its a positive but not so strong correlation.
# Out:
# (0.39782635452407639, 8.0994882554057922e-13)

# %%
#pos_by_sent vs ratings
plt.scatter( yelp_df['rating'], yelp_df['positive_by_sent'],s=100, marker='o',
            color='pink', alpha=0.75,edgecolor='grey')
plt.ylabel('Positive score of restr')
plt.xlabel('Restr rating')
plt.show()
#the chart below shows that even though restrs have low positive score it does not affect the ratings

# %%
#calculating pearson correlation
pos_corr = scipy.stats.pearsonr(yelp_df['positive_by_sent'], yelp_df['rating'])
pos_corr

#there is a high correlation between positive score and ratings of a restaurant.
#also p-value is <0.1, which shows the relation is highly significant
#this means -  positive review score can help build the good ratings(stars) for a restraurant
# Out:
# (0.80155698780920925, 1.5813200908265016e-68)

# %%
#calculating pearson correlation
neg_corr = scipy.stats.pearsonr(yelp_df['negative_by_sent'], yelp_df['rating'])
neg_corr1 = numpy.corrcoef(yelp_df['negative_by_sent'], yelp_df['rating'])[-1,0]
neg_corr

# there is no high correlation between negative score of reviews and restraurant ratings.just positive 0.31
#the relation is significant as p-value is <0.1, but correlation is not so strong. 
#this does not prove negative review score and restraunt rating means high/low restraunt ratings
# Out:
# (0.31423972044151272, 2.6733675572134901e-08)

# %%
#calculating pearson correlation
reviews_corr = scipy.stats.pearsonr(yelp_df['num_reviews'], yelp_df['rating'])
reviews_corr1 = numpy.corrcoef(yelp_df['num_reviews'], yelp_df['rating'])[-1,0]
reviews_corr1
# Out:
# 0.22358315662138933
